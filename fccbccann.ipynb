# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
import numpy

# random seed for reproducibility
numpy.random.seed(2)



# Read in muffin and cupcake ingredient data
from google.colab import files
uploaded = files.upload()
import io
# loading load prima indians diabetes dataset, past 5 years of medical history 
dataset = numpy.genfromtxt("fccbcc.csv", delimiter=",")
# Out:
#      <input type="file" id="files-3259c552-c608-46bc-b8f8-ab0000bb3d52" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3259c552-c608-46bc-b8f8-ab0000bb3d52">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving fccbcc.csv to fccbcc (1).csv

# %%
# split into input (X) and output (Y) variables, splitting csv data
X = dataset[:,1:3]
Y = dataset[:,0]

# split X, Y into a train and test set
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=40)

# create model, add dense layers one by one specifying activation function
model = Sequential()
model.add(Dense(5, input_dim=2, activation='relu')) # input layer requires input_dim param
#model.add(Dense(9, activation='relu'))
model.add(Dense(3, activation='relu'))
model.add(Dropout(.2))
model.add(Dense(1, activation='relu')) # sigmoid instead of relu for final probability between 0 and 1

# compile the model, adam gradient descent (optimized)
model.compile(loss="binary_crossentropy", optimizer="Adam", metrics=['accuracy'])

# call the function to fit to the data (training the network)
model.fit(x_train, y_train, epochs = 1000, batch_size=10, validation_data=(x_test, y_test))

# save the model
model.save('weights.h5')
# Out:
# Epoch 1/1000
# 34/34 [==============================] - 0s 5ms/step - loss: nan - accuracy: 0.4639 - val_loss: nan - val_accuracy: 0.5301
# Epoch 2/1000
# 34/34 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4639 - val_loss: nan - val_accuracy: 0.5301
# Epoch 3/1000
# 34/34 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4639 - val_loss: nan - val_accuracy: 0.5301
# Epoch 4/1000
# 34/34 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4639 - val_loss: nan - val_accuracy: 0.5301
# Epoch 5/1000
# 34/34 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4639 - val_loss: nan - val_accuracy: 0.5301
# Epoch 6/1000
# 34/34 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4639 - val_loss: nan - val_accuracy: 0.5301
# Epoch 7/1000
# 34/34 [==============================] - 0s 2ms/step - loss: nan - accuracy: 0.4639 - val_loss: nan - val_accuracy: 0.5301
# Epoch 8/1000
# ...

# %%
from keras.models import load_model
model = load_model('weights.h5')
y_pred=model.predict([[0.00143, 0.001343]])
y_pred = (y_pred > 0.5)
print(y_pred)
# Out:
# [[False]]

# %%
# !pip3 install keras
# !pip3 install ann_visualizer
# !pip install graphviz
#!pip install ann_visualizer
#!pip install graphviz
# Out:
# ...
#   Created wheel for ann-visualizer: filename=ann_visualizer-2.5-cp36-none-any.whl size=4171 sha256=5ed4a720cfc75cc6572d37841c6ecab5d1367291dc0be449a1527c98073eb928
#   Stored in directory: /root/.cache/pip/wheels/b6/b4/4e/d92f50c9c4f004cf315a0e0fcd455486bd799c50fe80cf1f5d
# Successfully built ann-visualizer
# ...

# %%
# !sudo apt-get install graphviz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# 0 upgraded, 0 newly installed, 0 to remove and 14 not upgraded.

# %%
from ann_visualizer.visualize import ann_viz;
ann_viz(model, view=True, title="FCC_BCC ANN", filename="fcc_bcc_ann")
